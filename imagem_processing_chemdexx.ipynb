# %%
from Imagem_processing_chemdexx.utils import io, plot
from Imagem_processing_chemdexx.processing import combination, transformation

# %%
image1 = io.read_image('C:/Users/carlo/OneDrive/Imagens/pendrive_fotos _quadro/IMG_1936.jpg')
image2 = io.read_image('C:/Users/carlo/OneDrive/Imagens/pendrive_fotos _quadro/IMG_1983.jpg')

# %%
plot.plot_image(image1)
plot.plot_image(image2)

# %%
combination.transfer_histogram(image1, image2)
# Out:
# array([[[204, 210, 237],
#         [204, 210, 237],
#         [204, 210, 237],
#         ...,
#         [209, 221, 238],
#         [209, 221, 238],
#         [210, 222, 238]],
#
#        [[204, 210, 237],
#         [204, 210, 237],
#         [204, 210, 237],
#         ...,
#         [209, 221, 238],
#         [209, 221, 238],
#         [209, 221, 238]],
#
#        [[204, 210, 237],
#         [204, 210, 237],
#         [204, 210, 237],
#         ...,
#         [209, 221, 238],
#         [210, 222, 238],
#         [210, 222, 238]],
#
#        ...,
#
#        [[209, 221, 238],
#         [209, 222, 238],
#         [209, 221, 238],
#         ...,
#         [205, 183, 187],
#         [205, 183, 187],
#         [206, 184, 188]],
#
#        [[209, 221, 238],
#         [209, 222, 238],
#         [209, 221, 238],
#         ...,
#         [205, 183, 187],
#         [205, 183, 187],
#         [206, 184, 188]],
#
#        [[209, 221, 238],
#         [209, 222, 238],
#         [209, 222, 238],
# ...

# %%
result_image = combination.transfer_histogram(image1, image2)
plot.plot_results(image1, image2, result_image)

# %%
result_image = combination.transfer_histogram(image2, image1)
plot.plot_results(image2, image1, result_image)
